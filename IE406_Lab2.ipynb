# %% [markdown]
# <a href="https://colab.research.google.com/github/nishi1612/Machine-Learning/blob/master/IE406_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd

# %%
def gradient_descent(init_theta,learning_rate):
  theta_history = np.zeros((10000,init_theta.shape[0]))
  y_list = []
  theta_history[0] = init_theta
  y_list.append(func(init_theta))
  iters = 1
  theta_new = init_theta
  f = False
  it = 10000
  while(True):
    der = derivative(theta_new)
    for i in range(theta_new.shape[0]):
      temp = theta_new[i]
      theta_new[i] = theta_new[i] - learning_rate*der[i] 
      if(abs(temp-theta_new[i])<0.0000001):
        f=True
    theta_history[iters] = theta_new
    y_list.append(func(theta_new))
    iters+=1
    if(iters>=it):
      break
    if(f):
      break
  print("For learning rate ",learning_rate," : ",iters," number of iterations required")
  plt.plot(y_list)
  plt.show()
  return theta_history[:iters]

# %%
def steepest_gradient_descent(init_theta,init_learning_rate):
  theta_history = np.zeros((10000,init_theta.shape[0]))
  y_list = []
  theta_history[0] = init_theta
  y_list.append(func(init_theta))
  iters = 1
  theta_new = init_theta
  learning_rate = init_learning_rate
  f = False
  it = 10000
  alphas = []
  while(True):
    der = derivative(theta_new)
    alphas.append(learning_rate)
    for i in range(theta_new.shape[0]):
      temp = theta_new[i]
      theta_new[i] = theta_new[i] - learning_rate*der[i] 
      if(abs(temp-theta_new[i])<0.0000000001):
          f=True    
    learning_rate = learning_rate - get_derivative(theta_history[iters-1],theta_new,der)
    theta_history[iters] = theta_new
    y_list.append(func(theta_new))
    iters+=1
    if(func(theta_new)==0):
      break
    if(iters>=it):
      break
    if(f):
      break
  print("For learning rate ",init_learning_rate," : ",iters," number of iterations required")
  plt.plot(y_list)
  plt.show()
  return theta_history[:iters]

# %%
def func(x):
  return x**2

def derivative(x):
  return 2*x

x = np.linspace(-2.5,2.5,100)

print("Gradient Descent")

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = gradient_descent(theta_init,0.1)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

def get_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -1*theta_new
  denominator = 2*theta_old
  return numerator/denominator

print("Steepest Gradient Descent")

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = steepest_gradient_descent(theta_init,0.0001)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = steepest_gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()
# Out:
# Gradient Descent
# For learning rate  0.01  :  641  number of iterations required
# For learning rate  0.1  :  71  number of iterations required
# Steepest Gradient Descent
# For learning rate  0.0001  :  3  number of iterations required
# For learning rate  0.01  :  3  number of iterations required

# %%
def func(x):
  return (x-1)**2

def derivative(x):
  return 2*(x-1)

x = np.linspace(-1.5,3.5,100)

print("Gradient Descent")

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = gradient_descent(theta_init,0.1)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

def get_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -2 * der * (theta_new - 1)
  denominator = 2 * der**2
  return numerator/denominator

print("Steepest Gradient Descent")

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = steepest_gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = steepest_gradient_descent(theta_init,0.1)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()
# Out:
# Gradient Descent
# For learning rate  0.01  :  641  number of iterations required
# For learning rate  0.1  :  71  number of iterations required
# Steepest Gradient Descent
# For learning rate  0.01  :  3  number of iterations required
# For learning rate  0.1  :  3  number of iterations required

# %%
def func(x):
  return x[0]**2 + x[1]**2

def derivative(x):
  return 2*x

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.01)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.1)

def get_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -2 * (der[0]*theta_new[0] + der[1]*theta_new[1])
  denominator = 2 * (der[0]**2 + der[1]**2)
  return numerator/denominator

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = steepest_gradient_descent(theta_init,0.01)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = steepest_gradient_descent(theta_init,0.1)
# Out:
# For learning rate  0.01  :  661  number of iterations required
# For learning rate  0.1  :  72  number of iterations required
# For learning rate  0.01  :  3  number of iterations required
# For learning rate  0.1  :  3  number of iterations required

# %%
def func(x):
  return (x[0]-1)**2 + (x[1]-1)**2

def derivative(x):
  return 2*(x-1)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.01)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.1)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

def get_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -2 * ((theta_new[0]-1)*der[0] + (theta_new[1]-1)*der[1])
  denominator = 2 * (der[0]**2 + der[1]**2)
  return numerator/denominator

theta_history = steepest_gradient_descent(theta_init,0.01)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = steepest_gradient_descent(theta_init,0.1)
# Out:
# For learning rate  0.01  :  641  number of iterations required
# For learning rate  0.1  :  71  number of iterations required
# For learning rate  0.01  :  3  number of iterations required
# For learning rate  0.1  :  3  number of iterations required

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
id = "1m6BWQugtxeS614IffP-lj_FGHHCkd7gA"
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('data.csv')  
df = pd.read_csv('data.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=94, step=1)

# %%
x = df['x'].values
y = df['y'].values

# %%
x = (x-np.mean(x))/np.std(x)

# %%
plt.scatter(x,y)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
def func(theta,x=x,y=y):
  return np.sum((y-(theta[0]+theta[1]*x))**2)

def derivative(theta,x=x,y=y):
  vals = np.zeros((2))
  vals[0] = -2*np.sum(y-(theta[0]+theta[1]*x))
  vals[1] = -2*np.sum(np.dot((y-(theta[0]+theta[1]*x)),x))
  return vals

theta = np.ones((2))
theta[0] = 27
theta[1] = -5
theta_history = gradient_descent(theta,0.00001)
theta_history[theta_history.shape[0]-1]
# Out:
# For learning rate  1e-05  :  5564  number of iterations required
# array([23.71817839, -6.86694238])

# %%
def func(theta,x=x,y=y):
  return np.sum((y-(theta[0]+theta[1]*x))**2)

def derivative(theta,x=x,y=y):
  vals = np.zeros((2))
  j = random.randint(0,93)
  vals[0] = -2*y[j]-(theta[0]+theta[1]*x[j])
  vals[1] = -2*(y[j]-(theta[0]+theta[1]*x[j]))*x[j]
  return vals

theta = np.ones((2))
theta[0] = 22.5
theta[1] = -5.5
theta_history = gradient_descent(theta,0.000015)
theta_history[theta_history.shape[0]-1]
# Out:
# For learning rate  1.5e-05  :  447  number of iterations required
# array([22.97740096, -5.51932413])

# %%
def get_derivative(theta_old,theta_new,der,x=x,y=y):
  X = np.vstack([np.ones(len(x)), x]).transpose()
  X_dtheta_dx = np.matmul(X, np.vstack((der[0], der[1])))
  X_dtheta_dx_2 = X_dtheta_dx**2
  X_dtheta_dx_2 = np.sum(X_dtheta_dx_2)*len(x)
  numerator = np.sum(np.matmul((np.matmul(X, theta_old) - y).transpose(), X_dtheta_dx))
  denominator = X_dtheta_dx_2*len(x)
  return numerator/denominator

def func(theta,x=x,y=y):
  return np.sum((y-(theta[0]+theta[1]*x))**2)

def derivative(theta,x=x,y=y):
  vals = np.zeros((2))
  vals[0] = -2*np.sum(y-(theta[0]+theta[1]*x))
  vals[1] = -2*np.sum(np.dot((y-(theta[0]+theta[1]*x)),x))
  return vals

theta = np.ones((2))
theta[0] = 27
theta[1] = -5
theta_history = steepest_gradient_descent(theta,0.001)
theta_history[theta_history.shape[0]-1]
# Out:
# For learning rate  0.001  :  112  number of iterations required
# array([23.71808511, -6.86699545])

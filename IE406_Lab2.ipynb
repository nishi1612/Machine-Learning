# %% [markdown]
# <a href="https://colab.research.google.com/github/nishi1612/Machine-Learning/blob/master/IE406_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd

# %%
def graph():
  plt.xlabel('Number of iterations')
  plt.ylabel(r'$J(\theta)$')
  plt.title(r'Number of iterations v/s $J(\theta)$')
  plt.show()

# %%
def gradient_descent(init_theta,learning_rate):
  theta_history = np.zeros((10000,init_theta.shape[0]))
  y_list = []
  theta_history[0] = init_theta
  y_list.append(func(init_theta))
  iters = 1
  theta_new = init_theta
  f = False
  it = 10000
  while(True):
    der = func_derivative(theta_new)
    for i in range(theta_new.shape[0]):
      temp = theta_new[i]
      theta_new[i] = theta_new[i] - learning_rate*der[i] 
      if(abs(temp-theta_new[i])<0.0000001):
        f=True
    theta_history[iters] = theta_new
    y_list.append(func(theta_new))
    iters+=1
    if(func(theta_new)==0):
      break
    if(iters>=it):
      break
    if(f):
      break
  print("For learning rate ",learning_rate," : ",iters," iterations required")
  plt.plot(y_list)
  graph()
  return theta_history[:iters]

# %%
def steepest_gradient_descent(init_theta,init_learning_rate):
  theta_history = np.zeros((10000,init_theta.shape[0]))
  y_list = []
  theta_history[0] = init_theta
  y_list.append(func(init_theta))
  iters = 1
  theta_new = init_theta
  learning_rate = init_learning_rate
  f = False
  it = 10000
  while(True):
    der = func_derivative(theta_new)
    for i in range(theta_new.shape[0]):
      temp = theta_new[i]
      theta_new[i] = theta_new[i] - learning_rate*der[i] 
      if(abs(temp-theta_new[i])<0.0000000001):
          f=True    
    learning_rate = learning_rate - alpha_derivative(theta_history[iters-1],theta_new,der)
    theta_history[iters] = theta_new
    y_list.append(func(theta_new))
    iters+=1
    if(func(theta_new)==0):
      break
    if(iters>=it):
      break
    if(f):
      break
  print("For learning rate ",init_learning_rate," : ",iters," iterations required")
  plt.plot(y_list)
  graph()
  return theta_history[:iters]

# %%
def func(x):
  return x**2

def func_derivative(x):
  return 2*x

x = np.linspace(-2.5,2.5,100)
y = 2

def alpha_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -1*theta_new
  denominator = 2*theta_old
  return numerator/denominator

print("Gradient Descent")

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = gradient_descent(theta_init,0.1)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

print("Steepest Gradient Descent")

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = steepest_gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 2

theta_history = steepest_gradient_descent(theta_init,0.1)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()
# Out:
# Gradient Descent
# For learning rate  0.01  :  641  iterations required
# For learning rate  0.1  :  71  iterations required
# Steepest Gradient Descent
# For learning rate  0.01  :  3  iterations required
# For learning rate  0.1  :  3  iterations required

# %%
def func(x):
  return (x-1)**2

def func_derivative(x):
  return 2*(x-1)

def alpha_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -2 * der * (theta_new - 1)
  denominator = 2 * der**2
  return numerator/denominator

x = np.linspace(-1.5,3.5,100)

print("Gradient Descent Approach")

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = gradient_descent(theta_init,0.1)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

print("Steepest Gradient Descent Approach")

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = steepest_gradient_descent(theta_init,0.01)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()

theta_init = np.zeros((1))
theta_init[0] = 3

theta_history = steepest_gradient_descent(theta_init,0.1)
plt.plot(x,func(x),color = 'orange')
plt.scatter(theta_history,func(theta_history))
plt.show()
# Out:
# Gradient Descent Approach
# For learning rate  0.01  :  641  iterations required
# For learning rate  0.1  :  71  iterations required
# Steepest Gradient Descent Approach
# For learning rate  0.01  :  3  iterations required
# For learning rate  0.1  :  3  iterations required

# %%
def func(x):
  return x[0]**2 + x[1]**2

def func_derivative(x):
  return 2*x

def alpha_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -2 * (der[0]*theta_new[0] + der[1]*theta_new[1])
  denominator = 2 * (der[0]**2 + der[1]**2)
  return numerator/denominator

print("Gradient Descent Approach")

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.01)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.1)

print("Steepest Gradient Descent Approach")

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = steepest_gradient_descent(theta_init,0.01)

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = steepest_gradient_descent(theta_init,0.1)
# Out:
# Gradient Descent Approach
# For learning rate  0.01  :  661  iterations required
# For learning rate  0.1  :  72  iterations required
# Steepest Gradient Descent Approach
# For learning rate  0.01  :  3  iterations required
# For learning rate  0.1  :  3  iterations required

# %%
def func(x):
  return (x[0]-1)**2 + (x[1]-1)**2

def func_derivative(x):
  return 2*(x-1)

def alpha_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = -2 * ((theta_new[0]-1)*der[0] + (theta_new[1]-1)*der[1])
  denominator = 2 * (der[0]**2 + der[1]**2)
  return numerator/denominator

print("Gradient Descent Approach")

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.01)
print(theta_history[theta_history.shape[0]-1])

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = gradient_descent(theta_init,0.1)
print(theta_history[theta_history.shape[0]-1])

print("Steepest Gradient Descent Approach")

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = steepest_gradient_descent(theta_init,0.01)
print(theta_history[theta_history.shape[0]-1])

theta_init = np.zeros((2))
theta_init[0] = 3
theta_init[1] = 4.5

theta_history = steepest_gradient_descent(theta_init,0.1)
print(theta_history[theta_history.shape[0]-1])
# Out:
# Gradient Descent Approach
# For learning rate  0.01  :  641  iterations required
# [1.00000485 1.00000849]
# For learning rate  0.1  :  71  iterations required
# [1.00000033 1.00000058]
# Steepest Gradient Descent Approach
# For learning rate  0.01  :  3  iterations required
# [1. 1.]
# For learning rate  0.1  :  3  iterations required
# [1. 1.]

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
id = "1m6BWQugtxeS614IffP-lj_FGHHCkd7gA"
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('data.csv')  
df = pd.read_csv('data.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=94, step=1)

# %%
x = df['x'].values
y = df['y'].values

# %%
x = (x-np.mean(x))/np.std(x)

# %%
plt.scatter(x,y)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
def func(theta,x=x,y=y):
  return np.sum((y-(theta[0]+theta[1]*x))**2)

def func_derivative(theta,x=x,y=y):
  vals = np.zeros((2))
  vals[0] = -2*np.sum(y-(theta[0]+theta[1]*x))
  vals[1] = -2*np.sum(np.dot((y-(theta[0]+theta[1]*x)),x))
  return vals

def alpha_derivative(theta_old,theta_new,der,x=x,y=y):
  numerator = 2 * np.sum(np.dot((y-theta[0]-theta[1]*x),(der[0] + der[1]*x)))
  denominator = 2 * np.sum((der[0] + der[1]*x)**2)
  return numerator/denominator

print("Gradient Descent Approach")

theta = np.ones((2))
theta[0] = 27
theta[1] = -5
theta_history = gradient_descent(theta,0.00001)
print(theta_history[theta_history.shape[0]-1])

print("Steepest Gradient Descent Approach")

theta = np.ones((2))
theta[0] = 27
theta[1] = -5
theta_history = steepest_gradient_descent(theta,0.001)
print(theta_history[theta_history.shape[0]-1])
# Out:
# Gradient Descent Approach
# For learning rate  1e-05  :  5564  iterations required
# [23.71817839 -6.86694238]
# Steepest Gradient Descent Approach
# For learning rate  0.001  :  4  iterations required
# [23.71808511 -6.86699545]

# %%
def func_derivative(theta,x=x,y=y):
  vals = np.zeros((2))
  j = random.randint(0,93)
  vals[0] = -2*y[j]-(theta[0]+theta[1]*x[j])
  vals[1] = -2*(y[j]-(theta[0]+theta[1]*x[j]))*x[j]
  return vals

print("Stochastic Gradient Descent Approach")

theta = np.ones((2))
theta[0] = 22.5
theta[1] = -5.5
theta_history = gradient_descent(theta,0.000015)
print(theta_history[theta_history.shape[0]-1])
# Out:
# Stochastic Gradient Descent Approach
# For learning rate  1.5e-05  :  686  iterations required
# [23.22395038 -5.52625528]
